# %%
import os
import pandas as pd
import numpy as np
from gensim.models import Word2Vec
from nltk.stem.snowball import SnowballStemmer
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import re
import tqdm
import time
import datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
import sys
sys.path.insert(0, '../common/')
import csv_utils
import importlib
importlib.reload(csv_utils)
# Out:
# <module 'csv_utils' from '../common\\csv_utils.py'>

# %%
isRealTest = True

# %%
def hms_string(sec_elapsed):
    h = int(sec_elapsed / (60 * 60))
    m = int((sec_elapsed % (60 * 60)) / 60)
    s = sec_elapsed % 60.
    return "{}:{:>02}:{:>05.2f}".format(h, m, s)

# %%
path = os.path.join('..','data','train_data_v2.csv')
train_data = pd.read_csv(path)

# %%
path = os.path.join('..','data','test_data.csv')
test_data = pd.read_csv(path)

# %%
train_data.head()
# Out:
#    id                                          question1  \
# 0   0  What is the step by step guide to invest in sh...
# 1   1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2  How can I increase the speed of my internet co...
# 3   3  Why am I mentally very lonely? How can I solve...
# 4   4  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
stemmer=SnowballStemmer("english")
#example: stemmer.stem("having") -> have

# %%
# Create a set of stopwords
stop = set(stopwords.words('english'))

# %%
# This is the function makeing the lemmatization
lemma = WordNetLemmatizer()

# %%
# pre processing data
def cleanData(sentence):
    processedList = ""
    
    # convert to lowercase, ignore all special characters - keep only alpha-numericals and spaces (not removing full-stop here)
    sentence = re.sub(r'[^A-Za-z0-9\s.]',r'',str(sentence).lower())
    #sentence = re.sub(r'\n',r' ',sentence)
    
    # remove stop words
    sentence = " ".join([word for word in sentence.split() if word not in stop])
    # lemmatize
    #sentence = " ".join(lemma.lemmatize(word) for word in sentence.split())
    # stemming 
    sentence = " ".join(stemmer.stem(word) for word in sentence.split())
    return sentence

# %%
cleanData("I'm a women and you?")
# Out:
# 'im women'

# %%
def cleandf(df):
    df['question1_cleaned'] = df['question1'].map(lambda x: cleanData(x))
    df['question2_cleaned'] = df['question2'].map(lambda x: cleanData(x))
    
cleandf(train_data)
cleandf(test_data)

# %%
if isRealTest:
    train, test = train_data, test_data
else:
    train, test = train_test_split(train_data, test_size=0.33)
print(train.shape)
print(test.shape)
# Out:
# (323160, 6)
# (81126, 5)

# %%
train['merged_cleaned'] = train['question1_cleaned'] + train['question2_cleaned']

# %%
train_data.head()
# Out:
#    id                                          question1  \
# 0   0  What is the step by step guide to invest in sh...
# 1   1  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2  How can I increase the speed of my internet co...
# 3   3  Why am I mentally very lonely? How can I solve...
# 4   4  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate  \
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0
#
#                                    question1_cleaned  \
# 0           step step guid invest share market india
# 1                    stori kohinoor kohinoor diamond
# 2             increas speed internet connect use vpn
# 3                                   mental lone solv
# 4  one dissolv water quik sugar salt methan carbo...
#
#                                    question2_cleaned  \
# 0                 step step guid invest share market
# 1  would happen indian govern stole kohinoor kohi...
# 2                    internet speed increas hack dns
# 3               find remaind math2324math divid 2423
# 4                       fish would surviv salt water
#
#                                       merged_cleaned
# 0  step step guid invest share market indiastep s...
# 1  stori kohinoor kohinoor diamondwould happen in...
# 2  increas speed internet connect use vpninternet...
# 3  mental lone solvfind remaind math2324math divi...
# 4  one dissolv water quik sugar salt methan carbo...

# %%
cleaned_sentences = train['merged_cleaned'].map(lambda x: x.split('.'))

# %%
# corpus [[w1,w2,w3..],[..]]

corpus = []
col = cleaned_sentences

for line in col.tolist():
    for list_i in line:
        words = [x for x in list_i.split()]
        corpus.append(words)

# %%
len(corpus)
# Out:
# 382519

# %%
size = 100 # default 100
window_size = 5 # default 5
epochs = 100
min_count = 5 # default 5
workers = 4

start_time = datetime.datetime.now()
# train word2vec model using gensim
model = Word2Vec(corpus, sg=1,window=window_size,size=size,
                 min_count=min_count,workers=workers,iter=epochs,sample=0.01)

end_time = datetime.datetime.now()
seconds_elapsed = (end_time - start_time).total_seconds()
print("It took {} to execute this".format(hms_string(seconds_elapsed)))
# Out:
# It took 0:16:16.38 to execute this

# %%
#sentence_1 = 'This room is dirty'
#sentence_2 = 'dirty and disgusting room'
#
#distance = model.wv.n_similarity(sentence_1.lower().split(), sentence_2.lower().split())
#print(distance)

# %%
#sentence_1 = 'I like cats'
#sentence_2 = 'I do not like cats'
#
#distance = model.wv.n_similarity(sentence_1.lower().split(), sentence_2.lower().split())
#print(distance)

# %%
def avg_sentence_vector(words, model, num_features, index2word_set):
    #function to average all words vectors in a given paragraph
    featureVec = np.zeros((num_features,), dtype="float32")
    nwords = 0

    for word in words:
        if word in index2word_set:
            nwords = nwords+1
            featureVec = np.add(featureVec, model[word])

    if nwords>0:
        featureVec = np.divide(featureVec, nwords)
    return featureVec

index2word_set = set(model.wv.index2word)
#get average vector for sentence 1
sentence_1_avg_vector = avg_sentence_vector(sentence_1.split(), model=model, num_features=100, index2word_set=index2word_set)

#get average vector for sentence 2
sentence_2_avg_vector = avg_sentence_vector(sentence_2.split(), model=model, num_features=100, index2word_set=index2word_set)

sen1_sen2_similarity =  cosine_similarity(sentence_1_avg_vector.reshape(1, -1),sentence_2_avg_vector.reshape(1, -1))
value = sen1_sen2_similarity[0][0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
#def avg_sentence_vector(words, model, num_features, index2word_set):
#    #function to average all words vectors in a given paragraph
#    
#    nwords = 0
#    for word in words:
#        if word in index2word_set:
#            nwords = nwords+1
#    featureVec = np.zeros((nwords,), dtype="float32")
#    for word in words:
#        if word in index2word_set:
#            featureVec = np.add(featureVec, model[word])
#
#    if nwords>0:
#        featureVec = np.divide(featureVec, nwords)
#    return featureVec
#
#index2word_set = set(model.wv.index2word)
##get average vector for sentence 1
#sentence_1_avg_vector = avg_sentence_vector(sentence_1.split(), model=model, num_features=100, index2word_set=index2word_set)
#
##get average vector for sentence 2
#sentence_2_avg_vector = avg_sentence_vector(sentence_2.split(), model=model, num_features=100, index2word_set=index2word_set)
#
#sen1_sen2_similarity =  cosine_similarity(sentence_1_avg_vector.reshape(1, -1),sentence_2_avg_vector.reshape(1, -1))
#value = sen1_sen2_similarity[0][0]

# %%
value
# Out:
# 0.42730284

# %%
def print_accuracy(model, test, isRealTest, threshold=0.5):
    index2word_set = set(model.wv.index2word)
    
    calculate_avg_vector = lambda cleaned_question: avg_sentence_vector(cleaned_question.split(), model=model, num_features=100, index2word_set=index2word_set)
    cosine_similarity_func = lambda s1_avg_vec, s2_avg_vec: cosine_similarity(s1_avg_vec.reshape(1, -1),s2_avg_vec.reshape(1, -1))
    
    def pred(row):
        avg_vec_1 = calculate_avg_vector(row['question1_cleaned'])
        avg_vec_2 = calculate_avg_vector(row['question2_cleaned'])
        
        similarity = cosine_similarity_func(avg_vec_1, avg_vec_2)
        value = similarity[0][0]
        return 1 if value >= threshold else 0 # is duplicated
    
    
    test['predicted'] = test.apply(pred, axis=1)
    
    if not isRealTest:
        test['equal'] = test['is_duplicate'] == test['predicted']
        acc = np.sum(test['equal'])/len(test['equal'])
        print('Accuracy:',acc, 'Threshold: ',threshold)
        return acc
start = 0.4
end = 0.9
step = 0.04

#bestThreshold = 0
#acc = 0
#for thres in np.linspace(start,end,(end-start)/step):
#    acc_tmp = print_accuracy(model, train, thres)
#    if acc < acc_tmp:
#        bestThreshold = thres
        
#print_accuracy(model, test, isRealTest=False, threshold=0.9)
print_accuracy(model, test_data, isRealTest=isRealTest, threshold=0.9)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   if __name__ == '__main__':

# %%
test
# Out:
#        test_id                                          question1  \
# 0           15  What would a Trump presidency mean for current...
# 1           20                         Why do rockets look white?
# 2           21              What's causing someone to be jealous?
# 3           23                           How much is 30 kV in HP?
# 4           34          What is the best travel website in spain?
# 5           46  How did Darth Vader fought Darth Maul in Star ...
# 6           48  What are some examples of products that can be...
# 7           51  Will a Blu Ray play on a regular DVD player? I...
# 8           54          How GST affects the CAs and tax officers?
# 9           56                              Who is israil friend?
# 10          58  I was suddenly logged off Gmail. I can't remem...
# 11          72                  How I can speak English fluently?
# 12          73  How helpful is QuickBooks' auto data recovery ...
# 13          78         How can I make money through the Internet?
# 14          81  What is the right etiquette for wishing a Jeho...
# 15          88     Which is the best gaming laptop under 60k INR?
# 16          94        What is abstract expressionism in painting?
# 17         100  Will there really be any war between India and...
# 18         107       What's the difference between love and pity?
# 19         113                      What do you think China food?
# 20         121  What is the difference between a neutral state...
# 21         128  What is it like to work in Asahi India Glass? ...
# 22         132            How do I register my domain site email?
# 23         134  What is the strongest structure or strongest s...
# 24         139           What is the ideal life after retirement?
# 25         142  Which one is better polo diesel or grand i10 p...
# 26         143                       Does a black hole have mass?
# 27         148  How much would it cost to hire Jerry Seinfeld ...
# 28         151            How can I stop being afraid of working?
# 29         156  If I do not monetize YouTube videos & upload c...
# ...        ...                                                ...
# 81096   404175                   How can I live alone in college?
# 81097   404176          Are there any other Cleganes in Westeros?
# 81098   404177  I changed my tires at Costco three months ago....
# 81099   404179                   Which is the free mason website?
# 81100   404180  Which one is better in today's generation: B.t...
# 81101   404181  What are some different ways of doing seated r...
# 81102   404184  I am an introvert and couldnt guess the right ...
# 81103   404193  Taxes in India: Can I download a soft copy of ...
# 81104   404203  Which professors from IIT Guwahati would you l...
# 81105   404206  Has anybody run the MEEP software on a Windows...
# 81106   404207           Is it safe to drink tap water in Canada?
# 81107   404209   What is the fastest way to sign into Yahoo Mail?
# 81108   404213           What is the 2S class in Indian Railways?
# 81109   404216       What are your new year resolutions for 2017?
# 81110   404217  What more shocking moves can be expected by th...
# 81111   404223  Will travelling to Pakistan on a business visa...
# 81112   404235     What were the causes of Nationalism in Europe?
# 81113   404236  What's your take on the speech by PM of Pakist...
# 81114   404237        What are the reviews of SensoVision System?
# 81115   404243  How does Quora determine how many views an ans...
# 81116   404247  Among Bollywood stars, which actor or actress ...
# 81117   404248  What are some ways to simplify the square root...
# 81118   404252         What is the best free web hosting for php?
# 81119   404254  Is there any internship available for a studen...
# 81120   404263  How does the burning of fossil fuels contribut...
# 81121   404264  Is it safe to store an external battery power ...
# 81122   404265                  How can I gain weight on my body?
# 81123   404269  How do you diagnose antisocial personality dis...
# 81124   404270        What is the difference between who and how?
# 81125   404278          How did you prepare for AIIMS/NEET/AIPMT?
#
#                                                question2  \
# 0      How will a Trump presidency affect the student...
# 1            Why are rockets and boosters painted white?
# 2       What can I do to avoid being jealous of someone?
# 3      Where can I find a conversion chart for CC to ...
# 4                       What is the best travel website?
# 5      Does Quora have a character limit for profile ...
# 6      What are some of the products made from crude ...
# 7      How can you play a Blu Ray DVD on a regular DV...
# 8                            Why can't I do my homework?
# 9      Is my boyfriend lying about his true feelings ...
# 10     I can't remember my Gmail password or my recov...
# 11            How can I learn to speak English fluently?
# 12     What is the quickbooks customer support phone ...
# 13     What are some different ways to make money onl...
# 14     How important is it to be the first person to ...
# 15       Which is the best gaming laptop under Rs 60000?
# 16     What are some of the major influences of abstr...
# 17     Will there be a nuclear war between India and ...
# 18         What is the difference between love and pity?
# 19                     How do you think of Chinese food?
# 20     If every state of the USA declared war against...
# 21     When will we get the Call Letter after we get ...
# 22                     How do you register a .an domain?
# 23                    What is the strongest Kevlar cord?
# 24                         What's life after retirement?
# 25       What is the best diet for a growing decathlete?
# 26                 Does a black hole have a finite mass?
# 27     How much on average would it cost to video tap...
# 28           How do you stop being afraid of everything?
# 29     How do you upload movies on YouTube and moneti...
# ...                                                  ...
# 81096              Should I live alone while in college?
# 81097         Are there any other Cleganes in the world?
# 81098  If my daughter gets a flat tire while driving ...
# 81099  Who are the Freemasons and what exactly do the...
# 81100  Which one is a better career option, a B.Tech ...
# 81101  What are some different ways of doing cable ro...
# 81102  I am working in an IT company, and I am prepar...
# 81103  Is it safe to share PAN card scanned copy, Aad...
# 81104  Which Professors from IIT Delhi would you love...
# 81105  How do I install and use MEEP software on a Wi...
# 81106             Is it safe to drink tap water in Pune?
# 81107  What is the fastest way to sign into Yahoo Mai...
# 81108                   What is TQWL in IRCTC wait list?
# 81109  What will be your new year resolution for 2017...
# 81110  After demonetization, which could be next step...
# 81111  How do I apply for US tourist visa after getti...
# 81112               What were the causes of nationalism?
# 81113  What are your views on Nawaz Sharif's speech a...
# 81114  Is Lothar Matthaus Germany's greatest footballer?
# 81115      How are the number of views on Quora counted?
# 81116  Who are some Bollywood actors and actresses wh...
# 81117                     What is the square root of 98?
# 81118       What are the best free web hosting services?
# 81119  I am a 5th sem student pursuing computer engin...
# 81120  Why does CO2 contribute more to global warming...
# 81121         How do I make a safe and cheap power bank?
# 81122                  What should I eat to gain weight?
# 81123  What Does It Feel Like to have antisocial pers...
# 81124      What is the difference between "&" and "and"?
# 81125  How did you prepare for the AIIMS UG entrance ...
#
#                                        question1_cleaned  \
# 0      would trump presid mean current intern master ...
# 1                                      rocket look white
# 2                               what caus someon jealous
# 3                                          much 30 kv hp
# 4                               best travel websit spain
# 5          darth vader fought darth maul star war legend
# 6                          exampl product make crude oil
# 7                        blu ray play regular dvd player
# 8                               gst affect cas tax offic
# 9                                          israil friend
# 10     sudden log gmail. cant rememb gmail password r...
# 11                                speak english fluentli
# 12     help quickbook auto data recoveri support phon...
# 13                                   make money internet
# 14        right etiquett wish jehovah wit happi birthday
# 15                              best game laptop 60k inr
# 16                             abstract expression paint
# 17           realli war india pakistan uri attack effect
# 18                                 what differ love piti
# 19                                      think china food
# 20                     differ neutral state buffer state
# 21     like work asahi india glass pay scale one two ...
# 22                              regist domain site email
# 23           strongest structur strongest shape compress
# 24                                      ideal life retir
# 25               one better polo diesel grand i10 petrol
# 26                                       black hole mass
# 27           much would cost hire jerri seinfeld 12 hour
# 28                                      stop afraid work
# 29     monet youtub video upload copyright content ch...
# ...                                                  ...
# 81096                                   live alon colleg
# 81097                                     clegan westero
# 81098  chang tire costco three month ago. got flat ti...
# 81099                                  free mason websit
# 81100               one better today generat b.tech bsit
# 81101               differ way seat row benefit tradeoff
# 81102  introvert couldnt guess right career parent to...
# 81103              tax india download soft copi pan card
# 81104        professor iit guwahati would love see quora
# 81105           anybodi run meep softwar window platform
# 81106                        safe drink tap water canada
# 81107                        fastest way sign yahoo mail
# 81108                            2s class indian railway
# 81109                              new year resolut 2017
# 81110                shock move expect prime minist modi
# 81111  travel pakistan busi visa affect chanc get us ...
# 81112                                  caus nation europ
# 81113                    what take speech pm pakistan un
# 81114                             review sensovis system
# 81115                quora determin mani view answer get
# 81116        among bollywood star actor actress much act
# 81117                         way simplifi squar root 56
# 81118                             best free web host php
# 81119  internship avail student ceram technolog third...
# 81120             burn fossil fuel contribut global warm
# 81121  safe store extern batteri power bank usb devic...
# 81122                                   gain weight bodi
# 81123                     diagnos antisoci person disord
# 81124                                             differ
# 81125                              prepar aiimsneetaipmt
#
#                                        question2_cleaned  predicted
# 0      trump presid affect student present us plan st...          0
# 1                             rocket booster paint white          0
# 2                                   avoid jealous someon          0
# 3                         find convers chart cc horsepow          0
# 4                                     best travel websit          0
# 5                    quora charact limit profil descript          0
# 6                                 product made crude oil          1
# 7                    play blu ray dvd regular dvd player          1
# 8                                          cant homework          0
# 9          boyfriend lie true feel friend secret attract          0
# 10     cant rememb gmail password recoveri email. rec...          1
# 11                          learn speak english fluentli          1
# 12             quickbook custom support phone number usa          0
# 13         differ way make money onlin exclud sell thing          0
# 14        import first person wish someon happi birthday          0
# 15                             best game laptop rs 60000          1
# 16                    major influenc abstract expression          0
# 17                            nuclear war india pakistan          0
# 18                                      differ love piti          1
# 19                                     think chines food          0
# 20                  everi state usa declar war would win          0
# 21     get call letter get letter intent asahi india ...          0
# 22                                     regist .an domain          0
# 23                                 strongest kevlar cord          0
# 24                                       what life retir          0
# 25                              best diet grow decathlet          0
# 26                                 black hole finit mass          1
# 27      much averag would cost video tape 2 hour present          0
# 28                                   stop afraid everyth          0
# 29               upload movi youtub monet issu copyright          1
# ...                                                  ...        ...
# 81096                                   live alon colleg          1
# 81097                                       clegan world          0
# 81098  daughter get flat tire drive colleg safer chan...          0
# 81099                                    freemason exact          0
# 81100                one better career option b.tech bsc          0
# 81101               differ way cabl row benefit tradeoff          1
# 81102  work compani prepar civil servic exam. howev t...          0
# 81103  safe share pan card scan copi aadhar copi inco...          0
# 81104           professor iit delhi would love see quora          1
# 81105                  instal use meep softwar window pc          0
# 81106                          safe drink tap water pune          1
# 81107                fastest way sign yahoo mail classic          1
# 81108                               tqwl irctc wait list          0
# 81109                  new year resolut 2017 plan execut          1
# 81110  demonet could next step need taken indian gove...          0
# 81111           appli us tourist visa get h1b visa india          0
# 81112                                        caus nation          0
# 81113        view nawaz sharif speech un general assembl          0
# 81114           lothar matthaus germani greatest footbal          0
# 81115                            number view quora count          0
# 81116                  bollywood actor actress known act          1
# 81117                                      squar root 98          0
# 81118                          best free web host servic          1
# 81119  5th sem student pursu comput engin want projec...          0
# 81120             co2 contribut global warm water vapour          0
# 81121                         make safe cheap power bank          0
# 81122                                    eat gain weight          0
# 81123                   feel like antisoci person disord          1
# 81124                                             differ          1
# 81125                        prepar aiim ug entranc exam          0
#
# [81126 rows x 6 columns]

# %%
csv_utils.create_csvs(test_data.predicted, test_data.test_id.values)
# Out:
# saved in:  E:\Dropbox\folch\UVA\Applied Machine Learning\Project_quora\models\..\data\submissions\submission_0604PM-November-23-2018.csv

# %% [markdown]
# score: 0.69281
